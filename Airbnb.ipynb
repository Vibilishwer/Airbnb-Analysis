# %%
import pandas as pd
import urllib.parse
from pymongo import MongoClient

# %%
# # Connecting with MONGODB ATLAS

# client = pymongo.MongoClient("mongodb+srv://vibilishwer:<vibilishwer>@cluster0.eefu6ud.mongodb.net/")
# db = client.sample_airbnb
# col = db.listingsAndReviews

# %%
username = "Dinesh24"
password = "Din@9600"
# Escape username and password
escaped_username = urllib.parse.quote_plus(username)
escaped_password = urllib.parse.quote_plus(password)
# Construct the connection string with escaped username and password
connection_string = f"mongodb+srv://{escaped_username}:{escaped_password}@cluster0.qav8w7p.mongodb.net/?retryWrites=true&w=majority"
# Create a MongoClient
client = MongoClient(connection_string)
# Access the database and collection
db = client.sample_airbnb
col = db.listingsAndReviews

# %%
# username = "vibilishwer"
# password = "Password"

# # Escape username and password
# escaped_username = urllib.parse.quote_plus(username)
# escaped_password = urllib.parse.quote_plus(password)

# # Construct the connection string with escaped username and password
# connection_string = f"mongodb+srv://{escaped_username}:{escaped_password}@cluster0.eefu6ud.mongodb.net/?retryWrites=true&w=majority"

# # Create a MongoClient

# from pymongo import MongoClient

# # Replace the following with your MongoDB connection string
# mongo_uri = "your_mongodb_connection_string"

# # Create a MongoClient object
# client = MongoClient(mongo_uri)
# # client = MongoClient(connection_string)


# # Access the database and collection
# db = client.sample_airbnb
# col = db.listingsAndReviews

# %%
# from pymongo import MongoClient

# # Replace the following with your MongoDB connection string
# mongo_uri = "your_mongodb_connection_string"

# # Create a MongoClient object with adjusted timeout settings
# client = MongoClient(mongo_uri, serverSelectionTimeoutMS=5000)

# %%
rel_data = []
for i in col.find():
    data = dict(Id = i['_id'],
                Name = i.get('name'),
                Description = i['description'],
                Property_type = i['property_type'],
                Room_type = i['room_type'],
                Bed_type = i['bed_type'],
                Min_nights = int(i['minimum_nights']),
                Max_nights = (i['maximum_nights']),
                Cancellation_policy = i['cancellation_policy'],
                Accomodates = i['accommodates'],
                Total_bedrooms = i.get('bedrooms'),
                Total_beds =  i.get('beds'),
                Availability_365 = i['availability']['availability_365'],
                Price = i['price'],
                calculated_host_listing_count = i['host']['host_listings_count'],
                neighbourhood = i['host']['host_neighbourhood'],
                No_of_reviews = i['number_of_reviews'],
                Review_scores = i['review_scores'].get('review_scores_rating'),
                Amenities = ', '.join(i['amenities']),
                Host_id = i['host']['host_id'],
                Host_name = i['host']['host_name'],
                Street = i['address']['street'],
                Country = i['address']['country'],
                Country_code = i['address']['country_code'],
                Location_type = i['address']['location']['type'],
                Longitude = i['address']['location']['coordinates'][0],
                Latitude = i['address']['location']['coordinates'][1])
    rel_data.append(data)

# %%
DF = pd.DataFrame(rel_data)

# %%
DF.head()
# Out:
#          Id                                               Name  \
# 0  10120414                                  The LES Apartment
# 1  10006546                            Ribeira Charming Duplex
# 2   1001265                   Ocean View Waikiki Marina w/prkg
# 3  10021707                           Private Room in Bushwick
# 4  10108388  Sydney Hyde Park City Apartment (checkin from ...
#
#                                          Description Property_type  \
# 0  Dear guests, Would you just like to live in th...     Apartment
# 1  Fantastic duplex apartment with three bedrooms...         House
# 2  A short distance from Honolulu's billion dolla...   Condominium
# 3  Here exists a very cozy room for rent in a sha...     Apartment
# 4  Our city apartment is a bright, comfortable 1 ...     Apartment
#
#          Room_type  Bed_type  Min_nights Max_nights  \
# 0  Entire home/apt  Real Bed           3       1125
# 1  Entire home/apt  Real Bed           2         30
# ...

# %%
DF.columns
# Out:
# Index(['Id', 'Name', 'Description', 'Property_type', 'Room_type', 'Bed_type',
#        'Min_nights', 'Max_nights', 'Cancellation_policy', 'Accomodates',
#        'Total_bedrooms', 'Total_beds', 'Availability_365', 'Price',
#        'calculated_host_listing_count', 'neighbourhood', 'No_of_reviews',
#        'Review_scores', 'Amenities', 'Host_id', 'Host_name', 'Street',
#        'Country', 'Country_code', 'Location_type', 'Longitude', 'Latitude'],
#       dtype='object')

# %%
DF.isnull().sum()
# Out:
# Id                                  0
# Name                                0
# Description                         0
# Property_type                       0
# Room_type                           0
# Bed_type                            0
# Min_nights                          0
# Max_nights                          0
# Cancellation_policy                 0
# Accomodates                         0
# Total_bedrooms                      5
# Total_beds                         13
# Availability_365                    0
# Price                               0
# calculated_host_listing_count       0
# neighbourhood                       0
# No_of_reviews                       0
# Review_scores                    1474
# Amenities                           0
# Host_id                             0
# Host_name                           0
# Street                              0
# Country                             0
# Country_code                        0
# Location_type                       0
# ...

# %%
DF.Price = DF.Price.astype(str).astype(float)
DF.Review_scores = DF.Review_scores.astype('Int64')

# %%
DF.to_csv("airbnb_DATA.csv",index=False)

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Id                             5555 non-null   object
#  1   Name                           5555 non-null   object
#  2   Description                    5555 non-null   object
#  3   Property_type                  5555 non-null   object
#  4   Room_type                      5555 non-null   object
#  5   Bed_type                       5555 non-null   object
#  6   Min_nights                     5555 non-null   int64
#  7   Max_nights                     5555 non-null   object
#  8   Cancellation_policy            5555 non-null   object
#  9   Accomodates                    5555 non-null   int64
#  10  Total_bedrooms                 5550 non-null   float64
#  11  Total_beds                     5542 non-null   float64
# ...

# %%
# filling null value

# %%
DF.Total_bedrooms.fillna(DF.Total_bedrooms.mode()[0],inplace=True)
DF.Total_beds.fillna(DF.Total_beds.median(),inplace= True)
DF.Review_scores.fillna(DF.Review_scores.median(),inplace=True)

# %%
DF.isna().sum()
# Out:
# Id                               0
# Name                             0
# Description                      0
# Property_type                    0
# Room_type                        0
# Bed_type                         0
# Min_nights                       0
# Max_nights                       0
# Cancellation_policy              0
# Accomodates                      0
# Total_bedrooms                   0
# Total_beds                       0
# Availability_365                 0
# Price                            0
# calculated_host_listing_count    0
# neighbourhood                    0
# No_of_reviews                    0
# Review_scores                    0
# Amenities                        0
# Host_id                          0
# Host_name                        0
# Street                           0
# Country                          0
# Country_code                     0
# Location_type                    0
# Longitude                        0
# Latitude                         0
# ...

# %%
#checking Duplicate records
DF[DF.duplicated]
# Out:
# Empty DataFrame
# Columns: [Id, Name, Description, Property_type, Room_type, Bed_type, Min_nights, Max_nights, Cancellation_policy, Accomodates, Total_bedrooms, Total_beds, Availability_365, Price, calculated_host_listing_count, neighbourhood, No_of_reviews, Review_scores, Amenities, Host_id, Host_name, Street, Country, Country_code, Location_type, Longitude, Latitude]
# Index: []
#
# [0 rows x 27 columns]

# %%
DF['Country'].unique()
# Out:
# array(['United States', 'Portugal', 'Australia', 'Turkey', 'Brazil',
#        'Hong Kong', 'Canada', 'Spain', 'China'], dtype=object)

# %%
DF['neighbourhood'].replace("","Copacabana",inplace=True)

# %%
DF.reset_index(drop=True,inplace=True)
DF
# Out:
#             Id                                               Name  \
# 0     10120414                                  The LES Apartment
# 1     10006546                            Ribeira Charming Duplex
# 2      1001265                   Ocean View Waikiki Marina w/prkg
# 3     10021707                           Private Room in Bushwick
# 4     10108388  Sydney Hyde Park City Apartment (checkin from ...
# ...        ...                                                ...
# 5550   9937100                Frida's Centric&Stylish Studio Apt.
# 5551   9969335                 Central, Modern, University, Metro
# 5552   9796437                     Bright, Spacious, Sunlit 2 bed
# 5553   9895628                Duplex com vista para o J. Botanico
# 5554   9985696                                    Kadıköy-Altıyol
#
#                                             Description Property_type  \
# 0     Dear guests, Would you just like to live in th...     Apartment
# ...

# %%
DF['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Copacabana                   2047
# Le Plateau                    123
# Mong Kok                       90
# Waikiki                        76
# Downtown Montreal              74
#                              ...
# Battery Park City               1
# Pointe-Claire                   1
# Opéra - Grands Boulevards       1
# Parada de Lucas                 1
# Tompkinsville                   1
# Name: count, Length: 446, dtype: int64

# %%
DF['Country'].value_counts()
# Out:
# Country
# United States    1222
# Turkey            661
# Canada            649
# Spain             633
# Australia         610
# Brazil            606
# Hong Kong         600
# Portugal          555
# China              19
# Name: count, dtype: int64

# %%
DF['Property_type'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Apartment
# 1             House
# 2       Condominium
# 3         Apartment
# 4         Apartment
#            ...
# 5550           Loft
# 5551      Apartment
# 5552      Apartment
# 5553      Apartment
# 5554          House
# Name: Property_type, Length: 5555, dtype: object>

# %%
DF['Property_type'].unique()
# Out:
# array(['Apartment', 'House', 'Condominium', 'Loft', 'Serviced apartment',
#        'Guesthouse', 'Hostel', 'Bed and breakfast', 'Bungalow',
#        'Treehouse', 'Guest suite', 'Townhouse', 'Cabin', 'Villa', 'Other',
#        'Cottage', 'Boat', 'Chalet', 'Boutique hotel', 'Farm stay',
#        'Earth house', 'Aparthotel', 'Resort', 'Tiny house',
#        'Nature lodge', 'Hotel', 'Barn', 'Casa particular (Cuba)', 'Hut',
#        'Camper/RV', 'Heritage hotel (India)', 'Pension (South Korea)',
#        'Campsite', 'Houseboat', 'Castle', 'Train'], dtype=object)

# %%
DF['Room_type'].value_counts()
# Out:
# Room_type
# Entire home/apt    3489
# Private room       1983
# Shared room          83
# Name: count, dtype: int64

# %%
DF['Review_scores'].value_counts()
# Out:
# Review_scores
# 95     1733
# 100     982
# 98      291
# 96      286
# 97      281
# 93      244
# 94      223
# 90      213
# 99      188
# 80      167
# 92      158
# 89      113
# 91      112
# 87       97
# 88       77
# 85       55
# 86       48
# 84       43
# 60       41
# 83       39
# 70       25
# 82       19
# 20       16
# 81       12
# 78       11
# 75       11
# 40       10
# 76        9
# 73        8
# 79        8
# 67        5
# 72        5
# 74        5
# 77        4
# 71        4
# 65        3
# 68        3
# 69        2
# 50        2
# 53        1
# 64        1
# Name: count, dtype: Int64
